# %%
import pandas as pd 
import csv
#take csv file
data = pd.read_csv("AddAndLatAndLon.csv") 
#sort by name or number
data.sort_values("Number", inplace = True) 
# to drop duplicates
data.drop_duplicates(subset ="Address", 
                     keep = False, inplace = True) 
# to display data
data
# Out:
#       Number                                            Address   Latitude  \
# 0          0  ﻿"215 Boulevard Bineau, 92200 Neuilly-sur-Sein...  48.894997
# 1          1  "30 Boulevard Georges Seurat, 92200 Neuilly-su...  48.894944
# 2          2  "119 Rue Anatole France, 92300 Levallois-Perre...  48.894739
# 3          3  "1 Place de Verdun, 92300 Levallois-Perret, Fr...  48.894605
# 4          4  "7 Rue Jules Verne, 92300 Levallois-Perret, Fr...  48.894729
# ...      ...                                                ...        ...
# 2622    2622  "16 Rue Emmanuel Chabrier, 94440 Santeny, Fran...  48.735209
# 2625    2625       "16 Avenue d'Esbly, 77150 Lésigny, France"\n  48.736131
# 2626    2626       "17 Avenue d'Esbly, 77150 Lésigny, France"\n  48.736149
# 2633    2633  "6 Rue de Beauverger, 77173 Chevry-Cossigny, F...  48.733305
# 2634    2634  "11 Rue de Beauverger, 77173 Chevry-Cossigny, ...  48.734549
#
#       Longitude
# 0      2.265847
# 1      2.268740
# 2      2.282436
# 3      2.284982
# 4      2.299196
# ...         ...
# 2622   2.576253
# 2625   2.604155
# 2626   2.604897
# 2633   2.670408
# 2634   2.670640
#
# [2143 rows x 4 columns]

# %%
#output to another csvfile
data.to_csv("AddAndLatAndLonNodup_1.csv")
